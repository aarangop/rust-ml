# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
# Create sample system of linear equations with two features and four examples to demonstrate learning using gradient descent
x = np.array([[1, 2], [2, 3], [3, 4], [4, 5]]).T
y = np.array([15, 18, 20, 25])

# Initialize weights and bias
w = np.random.randn(2)  # Two weights for two features
b = 0

print(f"Initial weights: {w}, Initial bias: {b}")
print(f"Input features:\n{x}")
# Out:
# Initial weights: [-1.32703468  0.21562859], Initial bias: 0
# Input features:
# [[1 2 3 4]
#  [2 3 4 5]]

# %%
# Define learning rate and number of iterations
learning_rate = 0.01
iterations = 1000

costs = np.array([])

# Gradient descent for linear regression
for i in range(iterations):
  # Compute predictions
  y_hat = w.T @ x + b
  
  # Compute gradients
  dw = -2 * np.sum((y - y_hat) * x) / len(x)
  db = -2 * np.sum(y - y_hat) / len(x)
  
  # Update weights and bias
  w -= learning_rate * dw
  b -= learning_rate * db

  # Compute cost
  cost = (y_hat - y) ** 2
  cost = 1/2 *  np.sum(cost) * 1 / len(x)
  costs = np.append(costs, cost)
  if i % 200 == 0:
    print(f"Iteration {i}: Cost {cost}, Weights {w}, Bias {b}")

print(f"Final weights: {w}, Final bias: {b}")
# Out:
# Iteration 0: Cost 510.4562449016381, Weights [4.39919872 5.94186199], Bias 0.882515465523019
# Iteration 200: Cost 1.7875334775726541, Weights [1.31239594 2.8550592 ], Bias 5.832821760769819
# Iteration 400: Cost 0.6471204927511457, Weights [1.01436943 2.5570327 ], Bias 7.863406123619799
# Iteration 600: Cost 0.4790508531666588, Weights [0.89995826 2.44262153], Bias 8.642939285365463
# Iteration 800: Cost 0.45428140198886513, Weights [0.85603627 2.39869954], Bias 8.942198927751503
# Final weights: [0.83922521 2.38188848], Final bias: 9.05674000725192

# %%
# Plot the cost function

plt.plot(costs)
plt.title("Cost Function")
plt.xlabel("Iterations")
plt.ylabel("Cost")
plt.grid()
plt.show()

# %%
# Compute the weights, and the bias that minimize the least squares error for y_hat = w.T * x + b
def compute_weights(x, y):
    # Solve for w and b
    
    return w

params = compute_weights(x, y)
w = params[0]
b = params[1]

print(f"Weights: {w}")
print(f"Bias: {b}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 7
#       4     w = np.linalg.lstsq(x, y, rcond=None)
#       5     return w
# ----> 7 params = compute_weights(x, y)
#       8 w = params[0]
#       9 b = params[1]
#
# Cell In[14], line 3, in compute_weights(x, y)
#       2 def compute_weights(x, y):
# ----> 3     x = np.vstack([x, np.ones(len(x))]).T  # Add bias term
#       4     w = np.linalg.lstsq(x, y, rcond=None)
#       5     return w
#
# File ~/repos/ml/rust-ml/.venv/lib/python3.12/site-packages/numpy/_core/shape_base.py:292, in vstack(tup, dtype, casting)
#     290 if not isinstance(arrs, tuple):
#     291     arrs = (arrs,)
# --> 292 return _nx.concatenate(arrs, 0, dtype=dtype, casting=casting)
#
# ...

# %%
# Make predictions using the computed weights
print(x.shape)
y_hat = np.dot(w.T, x) + b
# Out:
# (4,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 3
#       1 # Make predictions using the computed weights
#       2 print(x.shape)
# ----> 3 y_hat = np.dot(w.T, x) + b
#
# ValueError: shapes (2,) and (4,) not aligned: 2 (dim 0) != 4 (dim 0)

# %%
plt.scatter(x, y, marker='o', color='blue', label='Data Points')
plt.plot(x, np.dot() + params[1], color='red', label='Fitted Line')
plt.title('Sample Plot with Fitted Line')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()
plt.grid(True)
plt.show()
